# %% [markdown]
# ### Adversarial Patch Creation
# Developed by Tal Erez

# %%
# !pip install torch torchvision adversarial-robustness-toolbox matplotlib


import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
from art.attacks.evasion import FastGradientMethod
from art.estimators.classification import PyTorchClassifier
# Out:
# Collecting torch
#   Using cached torch-2.4.1-cp39-none-macosx_11_0_arm64.whl (62.1 MB)
# Collecting torchvision
#   Using cached torchvision-0.19.1-cp39-cp39-macosx_11_0_arm64.whl (1.7 MB)
# Collecting adversarial-robustness-toolbox
#   Using cached adversarial_robustness_toolbox-1.18.1-py3-none-any.whl (1.7 MB)
# Collecting filelock
#   Using cached filelock-3.15.4-py3-none-any.whl (16 kB)
# Collecting fsspec
#   Using cached fsspec-2024.9.0-py3-none-any.whl (179 kB)
# Collecting sympy
#   Using cached sympy-1.13.2-py3-none-any.whl (6.2 MB)
# Collecting jinja2
#   Using cached jinja2-3.1.4-py3-none-any.whl (133 kB)
# Collecting networkx
#   Using cached networkx-3.2.1-py3-none-any.whl (1.6 MB)
# Requirement already satisfied: typing-extensions>=4.8.0 in ./venv/lib/python3.9/site-packages (from torch) (4.12.2)
# Collecting pillow!=8.3.*,>=5.3.0
#   Using cached pillow-10.4.0-cp39-cp39-macosx_11_0_arm64.whl (3.4 MB)
# Collecting numpy
#   Using cached numpy-2.0.2-cp39-cp39-macosx_14_0_arm64.whl (5.3 MB)
# Requirement already satisfied: setuptools in ./venv/lib/python3.9/site-packages (from adversarial-robustness-toolbox) (58.0.4)
# Collecting tqdm
#   Using cached tqdm-4.66.5-py3-none-any.whl (78 kB)
# Collecting scikit-learn>=0.22.2
#   Using cached scikit_learn-1.5.1-cp39-cp39-macosx_12_0_arm64.whl (11.0 MB)
# Collecting scipy>=1.4.1
#   Using cached scipy-1.13.1-cp39-cp39-macosx_12_0_arm64.whl (30.3 MB)
# Requirement already satisfied: six in ./venv/lib/python3.9/site-packages (from adversarial-robustness-toolbox) (1.16.0)
# Collecting joblib>=1.2.0
#   Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Collecting threadpoolctl>=3.1.0
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Collecting MarkupSafe>=2.0
#   Using cached MarkupSafe-2.1.5-cp39-cp39-macosx_10_9_universal2.whl (18 kB)
# Collecting mpmath<1.4,>=1.1.0
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: numpy, mpmath, MarkupSafe, threadpoolctl, sympy, scipy, networkx, joblib, jinja2, fsspec, filelock, tqdm, torch, scikit-learn, pillow, torchvision, adversarial-robustness-toolbox
# Successfully installed MarkupSafe-2.1.5 adversarial-robustness-toolbox-1.18.1 filelock-3.15.4 fsspec-2024.9.0 jinja2-3.1.4 joblib-1.4.2 mpmath-1.3.0 networkx-3.2.1 numpy-2.0.2 pillow-10.4.0 scikit-learn-1.5.1 scipy-1.13.1 sympy-1.13.2 threadpoolctl-3.5.0 torch-2.4.1 torchvision-0.19.1 tqdm-4.66.5
# WARNING: You are using pip version 21.2.4; however, version 24.2 is available.
# You should consider upgrading via the '/Users/talerez/Documents/AIPI_590_XAI/AdversarialAI_Patch/venv/bin/python3 -m pip install --upgrade pip' command.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 9
#       7 import torchvision
#       8 import torchvision.transforms as transforms
# ----> 9 import matplotlib.pyplot as plt
#      10 import numpy as np
#      11 from art.attacks.evasion import FastGradientMethod
#
# ModuleNotFoundError: No module named 'matplotlib'
